# %% [markdown]
# ***GENERATED CODE FOR amazon PIPELINE.***

# %% [markdown]
# ***DON'T EDIT THIS CODE.***

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO READ DATA.***

# %%
from utils import DataframeConversions
import boto3
import pandas as pd
import datetime
import json
import logging
import warnings
warnings.filterwarnings('ignore')
logging.basicConfig(format='%(levelname)s:%(message)s', level=logging.INFO)


class s3Connector:

    def fetch(self, inStages, inStagesData, stageId, spark, config):
                if type(config) == str:
            config = config.replace("'", '"')
            config = json.loads(config)
        region_name = config['region']

        aws_access_key_id = config['accessKeyId']
        aws_secret_access_key = config['secretAccessKey']
        bucket = config['bucket']
        key = config['url']

        s3 = boto3.resource(
            service_name='s3',
            region_name=region_name,
            aws_access_key_id=aws_access_key_id,
            aws_secret_access_key=aws_secret_access_key
        )
        obj = s3.Bucket(bucket).Object(key).get()
        pandaDF = pd.read_csv(obj['Body'])
        return pandaDF

    def put(self, inStages, inStagesData, stageId, spark, config):
        configObj = json.loads(config)
        region_name = configObj['region']
        aws_access_key_id = configObj['accessKeyId']
        aws_secret_access_key = configObj['secretAccessKey']
        key = configObj['url']
        bucket = configObj['bucket']
        filename = configObj['filename']
        df = inStagesData[inStages[0]]
        df.to_csv(filename)
        cwd = os.getcwd()
        url = cwd + '\\' + filename

        s3 = boto3.resource(
            service_name='s3',
            region_name=region_name,
            aws_access_key_id=aws_access_key_id,
            aws_secret_access_key=aws_secret_access_key
        )
        s3.Bucket(bucket).upload_file(Filename=url, Key=key)
        os.remove(url)
        return url

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO WRITE DATA.***

# %%
from utils import DataframeConversions
import boto3
import pandas as pd
import datetime
import json
import logging
import warnings
warnings.filterwarnings('ignore')
logging.basicConfig(format='%(levelname)s:%(message)s', level=logging.INFO)


class s3Connector:

    def fetch(self, inStages, inStagesData, stageId, spark, config):
                if type(config) == str:
            config = config.replace("'", '"')
            config = json.loads(config)
        region_name = config['region']

        aws_access_key_id = config['accessKeyId']
        aws_secret_access_key = config['secretAccessKey']
        bucket = config['bucket']
        key = config['url']

        s3 = boto3.resource(
            service_name='s3',
            region_name=region_name,
            aws_access_key_id=aws_access_key_id,
            aws_secret_access_key=aws_secret_access_key
        )
        obj = s3.Bucket(bucket).Object(key).get()
        pandaDF = pd.read_csv(obj['Body'])
        return pandaDF

    def put(self, inStages, inStagesData, stageId, spark, config):
        configObj = json.loads(config)
        region_name = configObj['region']
        aws_access_key_id = configObj['accessKeyId']
        aws_secret_access_key = configObj['secretAccessKey']
        key = configObj['url']
        bucket = configObj['bucket']
        filename = configObj['filename']
        df = inStagesData[inStages[0]]
        df.to_csv(filename)
        cwd = os.getcwd()
        url = cwd + '\\' + filename

        s3 = boto3.resource(
            service_name='s3',
            region_name=region_name,
            aws_access_key_id=aws_access_key_id,
            aws_secret_access_key=aws_secret_access_key
        )
        s3.Bucket(bucket).upload_file(Filename=url, Key=key)
        os.remove(url)
        return url

# %% [markdown]
# ***READING DATAFRAME***

# %%
#%run amazonHooks.ipynb
try:
	#sourcePreExecutionHook()

	predictivechurntrain = s3Connector.fetch(spark, "{'url': 'DemoTrainFiles/Classification Scenarios/Predictive Churn/PredictiveChurnTrain.csv', 'filename': 'PredictiveChurnTrain.csv', 'delimiter': ',', 'file_type': 'Delimeted', 'Username': 'numtradev', 'bucket': 'numtradevtest', 'region': 'us-east-2', 'accessKeyId': 'AKIAZWPSNC4LK7WATPNZ', 'secretAccessKey': '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', 'demoFolder': 'DemoTrainFiles/', 'dbtype': 'amazonS3', 'is_header': 'Use Header Line', 'server_url': '/numtraPlatform/NumtraPlatformV2/uploads/platform/'}")
	#sourcePostExecutionHook(predictivechurntrain)

except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***WRITING DATAFRAME***

# %%
#%run amazonHooks.ipynb
try:
	#sinkPreExecutionHook()

	amazons = s3Connector.put(df, "{'url': 'DemoTrainFiles/Classification Scenarios/Predictive Churn//predictive0001.csv', 'pathOnly': 'DemoTrainFiles/Classification Scenarios/Predictive Churn/', 'filename': 'predictive0001', 'delimiter': ',', 'file_type': 'Delimeted', 'Username': 'numtradev', 'bucket': 'numtradevtest', 'region': 'us-east-2', 'accessKeyId': 'AKIAZWPSNC4LK7WATPNZ', 'secretAccessKey': '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', 'demoFolder': 'DemoTrainFiles/', 'dbtype': 'amazonS3', 'is_header': 'Use Header Line', 'server_url': '/numtraPlatform/NumtraPlatformV2/uploads/platform/'}")
	#sinkPostExecutionHook(amazons)

except Exception as ex: 
	logging.error(ex)
